# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df = pd.read_csv("C:/Users/USER/Desktop/Desktop/Work/PAU/COS 102/diabetes/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#getting info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %% [markdown]
# ## Data Cleaning

# %%
#counting null values in each column
df.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#checking the shape of the dataframe
df.shape
# Out:
# (768, 9)

# %%
#filling the null values in Insulin column with the mean value
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())

# %%
#filling the null values in BloodPressure, SkinThickness and BMI column with the median value
to_fill = ['BloodPressure','SkinThickness', 'BMI']
for col in to_fill:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     5
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#dropping any row that contains a null value and making the change permanent
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0           35.0  155.548223  33.6
# 1              1     85.0           66.0           29.0  155.548223  26.6
# 2              8    183.0           64.0           29.0  155.548223  23.3
# 3              1     89.0           66.0           23.0   94.000000  28.1
# 4              0    137.0           40.0           35.0  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0           48.0  180.000000  32.9
# 764            2    122.0           70.0           27.0  155.548223  36.8
# 765            5    121.0           72.0           23.0  112.000000  26.2
# 766            1    126.0           60.0           29.0  155.548223  30.1
# 767            1     93.0           70.0           31.0  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Plotting the correlation heatmap of the dataset
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [raw]
# Some Insights:
# 1. There's a weak positive correlation between Age and pregnancies, which is logical because if you have an increasing number of pregnancies, it can be an indication of an higher Age, even though there can be other factors in play.
# 2. There's a weak positive correlation between BMI and Skin Thickness, since Skin Thickness is an indication of fat which translates to weight, but height also plays a role as well as bone density.

# %%
#Checking out the plain correlation data
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128135       0.207161       0.079325
# Glucose                      0.128135  1.000000       0.219236       0.193258
# BloodPressure                0.207161  0.219236       1.000000       0.191194
# SkinThickness                0.079325  0.193258       0.191194       1.000000
# Insulin                      0.054488  0.420825       0.073123       0.156741
# BMI                          0.018216  0.231765       0.279443       0.541679
# DiabetesPedigreeFunction    -0.036063  0.137246      -0.004387       0.099584
# Age                          0.542558  0.267136       0.323907       0.123589
# Outcome                      0.218877  0.494650       0.164187       0.211906
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.054488  0.018216                 -0.036063
# ...

# %%
#Counting the diabetic vs the non diabetic patients
plt.figure(figsize=(10, 8))
sns.countplot(x='Outcome', data=df)
plt.title("Outcome Count")
plt.show()

# %% [raw]
# Insight: The dataset is not balanced, there are about twice as many non diabetic patients as there are diabetic patients.

# %%
#Analyzing the distribution of the glucose level of the patients that make up the dataset
plt.figure(figsize=(10, 8))
sns.histplot(df['Glucose'], kde=True)
plt.title("Glucose Distribution")
plt.show()

# %% [raw]
# Insight: The glucose level distubution across the dataset is mostly a normal distribution

# %%
#Comparing the glucose distibution between the diabetic and non diabetic patients
plt.figure(figsize=(10, 8))
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title("Glucose vs Outcome")
plt.show()

# %% [raw]
# Insight: The glucose level figures are generally higher for the diabetic patients, with the median of the non diabetic being about 110 and that of the diabetic being about 140

# %%
#Comparing the BMI distibution between the diabetic and non diabetic patients
plt.figure(figsize=(10, 8))
sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title("BMI vs Outcome")
plt.show()

# %% [raw]
# Insight: The glucose level figures are generally higher for the diabetic patients, with the median of the non diabetic being about 110 and that of the diabetic being about 140

# %%
#Calculating the average values of each feature for diabetic and non-diabetic
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.311871  110.643863      70.965795      27.742455  142.396950
# 1           4.860902  142.319549      75.131579      31.650376  180.618641
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.902213                  0.430662  31.247485
# 1        35.348872                  0.550605  37.052632

# %% [raw]
# The average values for the diabetic is generally higher than the non diabetics. But it's good to note that average can be affected by outliers
